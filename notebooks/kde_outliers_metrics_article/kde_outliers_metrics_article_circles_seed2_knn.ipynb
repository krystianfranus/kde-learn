# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

from kdelearn.kde import KDE
from kdelearn.kde_funcs import KDEOutliersDetector
from kdelearn.bandwidth_selection import normal_reference, direct_plugin

from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# Przy
#
# a=0.00, 0.01, 0.02, 0.03, ... , 0.50
#
# oraz
#
# r=0.01, 0.015, 0.02, 0.025, ... , 0.2

# %%
def func(x_train):
    bandwidth = direct_plugin(x_train, stage=2)
    kde = KDE().fit(x_train, bandwidth=bandwidth)
    scores = kde.pdf(x_train)

    metrics_list = []
    r_list = []
    for r in np.arange(0.01, 0.205, 0.005):
        r = round(r, 3)
        
        # knn
        k = int(np.sqrt(m_train))
        nbrs = NearestNeighbors(n_neighbors=k, algorithm='brute').fit(x_train)
        distances, indices = nbrs.kneighbors(x_train)
        dist_k = np.max(distances, axis=1)
        threshold = np.quantile(dist_k, 1 - r)
        labels_pred = np.where(dist_k >= threshold, 1 ,0)

        n_outliers = labels_pred.sum()
        if n_outliers == 0:
            continue

        scores_o = scores[labels_pred==1]
        scores_i = scores[labels_pred==0]
        metrics = np.sum(scores_o) / np.sum(np.sort(scores_i)[:n_outliers])

        metrics_list.append(metrics)
        r_list.append(r)

    plt.plot(r_list, metrics_list, "-o")
    plt.xlabel("r")
    plt.ylabel("PI")
    plt.grid()
    plt.show()

    # Find minima
    idx = np.argmin(metrics_list)
    global_min = (metrics_list[idx], r_list[idx])
    
    print(f"r - globalne minimum: {global_min[1]:.3f}")
    print("-"*10)
    
    return global_min, scores

# %% [markdown]
# \newpage

# %%
for a in np.arange(0.0, 0.51, 0.01):
    print(f"a = {round(a, 2)}")
    seed = 2
    np.random.seed(seed)


    # Data
    m_train = 1000
    n_outliers = int(a * m_train)
    x_train = make_moons(n_samples=m_train, noise=0.05, random_state=seed)[0]
    x_train = np.concatenate([x_train, np.random.uniform(low=-1, high=1.75, size=(n_outliers, 2))], axis=0)
    
    # Run
    global_min, scores = func(x_train)
    
    plt.figure(figsize=(6, 3.8))
    threshold = np.quantile(scores, global_min[1])
    labels_pred = np.where(scores <= threshold, 1, 0)
    plt.scatter(x_train[:,0], x_train[:,1])
    plt.scatter(x_train[labels_pred==1,0], x_train[labels_pred==1,1], c="r")
    plt.show()
# Out:
# a = 0.0
# r - globalne minimum: 0.010
# ----------
# a = 0.01
# r - globalne minimum: 0.010
# ----------
# a = 0.02
# r - globalne minimum: 0.010
# ----------
# a = 0.03
# r - globalne minimum: 0.015
# ----------
# a = 0.04
# r - globalne minimum: 0.020
# ----------
# a = 0.05
# r - globalne minimum: 0.025
# ----------
# a = 0.06
# r - globalne minimum: 0.030
# ----------
# a = 0.07
# r - globalne minimum: 0.035
# ----------
# a = 0.08
# r - globalne minimum: 0.040
# ----------
# a = 0.09
# r - globalne minimum: 0.045
# ----------
# a = 0.1
# r - globalne minimum: 0.050
# ----------
# a = 0.11
# r - globalne minimum: 0.055
# ----------
# a = 0.12
# r - globalne minimum: 0.060
# ----------
# a = 0.13
# r - globalne minimum: 0.065
# ----------
# a = 0.14
# r - globalne minimum: 0.070
# ----------
# a = 0.15
# r - globalne minimum: 0.075
# ----------
# a = 0.16
# r - globalne minimum: 0.080
# ----------
# a = 0.17
# r - globalne minimum: 0.085
# ----------
# a = 0.18
# r - globalne minimum: 0.090
# ----------
# a = 0.19
# r - globalne minimum: 0.095
# ----------
# a = 0.2
# r - globalne minimum: 0.105
# ----------
# a = 0.21
# r - globalne minimum: 0.110
# ----------
# a = 0.22
# r - globalne minimum: 0.110
# ----------
# a = 0.23
# r - globalne minimum: 0.120
# ----------
# a = 0.24
# r - globalne minimum: 0.125
# ----------
# a = 0.25
# r - globalne minimum: 0.120
# ----------
# a = 0.26
# r - globalne minimum: 0.125
# ----------
# a = 0.27
# r - globalne minimum: 0.130
# ----------
# a = 0.28
# r - globalne minimum: 0.135
# ----------
# a = 0.29
# r - globalne minimum: 0.135
# ----------
# a = 0.3
# r - globalne minimum: 0.140
# ----------
# a = 0.31
# r - globalne minimum: 0.145
# ----------
# a = 0.32
# r - globalne minimum: 0.145
# ----------
# a = 0.33
# r - globalne minimum: 0.150
# ----------
# a = 0.34
# r - globalne minimum: 0.150
# ----------
# a = 0.35
# r - globalne minimum: 0.155
# ----------
# a = 0.36
# r - globalne minimum: 0.155
# ----------
# a = 0.37
# r - globalne minimum: 0.160
# ----------
# a = 0.38
# r - globalne minimum: 0.165
# ----------
# a = 0.39
# r - globalne minimum: 0.170
# ----------
# a = 0.4
# r - globalne minimum: 0.175
# ----------
# a = 0.41
# r - globalne minimum: 0.175
# ----------
# a = 0.42
# r - globalne minimum: 0.180
# ----------
# a = 0.43
# r - globalne minimum: 0.185
# ----------
# a = 0.44
# r - globalne minimum: 0.190
# ----------
# a = 0.45
# r - globalne minimum: 0.190
# ----------
# a = 0.46
# r - globalne minimum: 0.195
# ----------
# a = 0.47
# r - globalne minimum: 0.200
# ----------
# a = 0.48
# r - globalne minimum: 0.200
# ----------
# a = 0.49
# r - globalne minimum: 0.200
# ----------
# a = 0.5
# r - globalne minimum: 0.200
# ----------
